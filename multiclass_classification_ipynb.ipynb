# %% [markdown]
# <a href="https://colab.research.google.com/github/pratiksha12-stack/Data-Science/blob/main/multiclass_classification_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-66270929-cf5a-4dbd-ad9b-97a4db6fc455" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66270929-cf5a-4dbd-ad9b-97a4db6fc455">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#import os
#os.chdir("D")

# %%
df=pd.read_csv('predictive_maintenance.csv')
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UDI                      10000 non-null  int64
#  1   Product ID               10000 non-null  object
#  2   Type                     10000 non-null  object
#  3   Air temperature [K]      10000 non-null  float64
#  4   Process temperature [K]  10000 non-null  float64
#  5   Rotational speed [rpm]   10000 non-null  int64
#  6   Torque [Nm]              10000 non-null  float64
#  7   Tool wear [min]          10000 non-null  int64
#  8   Target                   10000 non-null  int64
#  9   Failure Type             10000 non-null  object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 781.4+ KB

# %%
df.isna().sum()
# Out:
# UDI                        0
# Product ID                 0
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Target                     0
# Failure Type               0
# dtype: int64

# %%
df.describe()
# Out:
#                UDI  Air temperature [K]  Process temperature [K]  \
# count  10000.00000         10000.000000             10000.000000
# mean    5000.50000           300.004930               310.005560
# std     2886.89568             2.000259                 1.483734
# min        1.00000           295.300000               305.700000
# 25%     2500.75000           298.300000               308.800000
# 50%     5000.50000           300.100000               310.100000
# 75%     7500.25000           301.500000               311.100000
# max    10000.00000           304.500000               313.800000
#
#        Rotational speed [rpm]   Torque [Nm]  Tool wear [min]        Target
# count            10000.000000  10000.000000     10000.000000  10000.000000
# mean              1538.776100     39.986910       107.951000      0.033900
# std                179.284096      9.968934        63.654147      0.180981
# min               1168.000000      3.800000         0.000000      0.000000
# ...

# %%
df['Failure Type'].value_counts()
# Out:
# No Failure                  9652
# Heat Dissipation Failure     112
# Power Failure                 95
# Overstrain Failure            78
# Tool Wear Failure             45
# Random Failures               18
# Name: Failure Type, dtype: int64

# %%
df['Type'].value_counts()
# Out:
# L    6000
# M    2997
# H    1003
# Name: Type, dtype: int64

# %%
pd.crosstab(index = df['Type'],columns = df['Failure Type'],dropna = True,normalize = 'columns',margins = True) # joint probability (liklihood of two independent event happening at same time)
# Out:
# Failure Type  Heat Dissipation Failure  No Failure  Overstrain Failure  \
# Type
# H                             0.071429    0.101430            0.012821
# L                             0.660714    0.596457            0.935897
# M                             0.267857    0.302114            0.051282
#
# Failure Type  Power Failure  Random Failures  Tool Wear Failure     All
# Type
# H                  0.052632         0.222222           0.133333  0.1003
# L                  0.621053         0.666667           0.555556  0.6000
# M                  0.326316         0.111111           0.311111  0.2997

# %%
pd.crosstab(index = df['Type'],columns = df['Failure Type'],dropna = True,normalize = 'index',margins= True) # normalize = 'columns'
# Out:
# Failure Type  Heat Dissipation Failure  No Failure  Overstrain Failure  \
# Type
# H                             0.007976    0.976072            0.000997
# L                             0.012333    0.959500            0.012167
# M                             0.010010    0.972973            0.001335
# All                           0.011200    0.965200            0.007800
#
# Failure Type  Power Failure  Random Failures  Tool Wear Failure
# Type
# H                  0.004985         0.003988           0.005982
# L                  0.009833         0.002000           0.004167
# M                  0.010344         0.000667           0.004671
# All                0.009500         0.001800           0.004500

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot = True,cmap = "RdYlBu")
plt.draw()
# Out:
# <ipython-input-12-74c42938877b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot = True,cmap = "RdYlBu")

# %%
df.hist(figsize=(16, 16),color = 'green',edgecolor = 'white',bins = 10)
# Out:
# array([[<Axes: title={'center': 'UDI'}>,
#         <Axes: title={'center': 'Air temperature [K]'}>,
#         <Axes: title={'center': 'Process temperature [K]'}>],
#        [<Axes: title={'center': 'Rotational speed [rpm]'}>,
#         <Axes: title={'center': 'Torque [Nm]'}>,
#         <Axes: title={'center': 'Tool wear [min]'}>],
#        [<Axes: title={'center': 'Target'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.set(style ="darkgrid")
sns.regplot(x = df["Air temperature [K]"],y = df["Process temperature [K]"],fit_reg = True,marker = "*")
# Out:
# <Axes: xlabel='Air temperature [K]', ylabel='Process temperature [K]'>

# %%
sns.set(style ="darkgrid")
sns.regplot(x = df["Rotational speed [rpm]"],y = df["Torque [Nm]"],fit_reg = True,marker = "*")
# Out:
# <Axes: xlabel='Rotational speed [rpm]', ylabel='Torque [Nm]'>

# %%
sns.lmplot(x="Rotational speed [rpm]",y ="Torque [Nm]",data = df,fit_reg= False ,hue = 'Failure Type',legend = True,palette = "Set1" )

# %%
Lsns.lmplot(x="Air temperature [K]",y ="Process temperature [K]",data = df,fit_reg= False ,hue = 'Failure Type',legend = True,palette = "Set1" )

# %%
df["Failure Type"].replace({"No Failure": 0,"Heat Dissipation Failure": 1,"Power Failure": 2,"Overstrain Failure": 3,"Tool Wear Failure": 4,"Random Failures": 5},inplace=True)

# %%
#df.head()

# %%
df["Type"].replace({"H":0,"L":1,"M":2}, inplace=True)

# %%
col_name=df.columns.to_list()
col_name
# Out:
# ['UDI',
#  'Product ID',
#  'Type',
#  'Air temperature [K]',
#  'Process temperature [K]',
#  'Rotational speed [rpm]',
#  'Torque [Nm]',
#  'Tool wear [min]',
#  'Target',
#  'Failure Type']

# %%
predictive_columns = col_name[2:6]
X = df[predictive_columns]
y = df["Failure Type"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=40, test_size=0.33)

# %%
X_test.shape
# Out:
# (3300, 4)

# %%
from imblearn.combine import SMOTETomek
smote = SMOTETomek(random_state=42)
X1_res, y1_res = smote.fit_resample(X_train,y_train)

# %%
df_x = pd.DataFrame(X1_res)
df_x["Type"].replace({0:"H",1:"L",2:"M"}, inplace=True)
df_y = pd.DataFrame(y1_res)
df_y["Failure Type"].replace({0:"No Failure",1:"Heat Dissipation Failure",2:"Power Failure",3:"Overstrain Failure",4:"Tool Wear Failure",5:"Random Failures"},inplace=True)
df1 = pd.concat([df_x,df_y], axis=1)

# %%
df1['Failure Type'].value_counts()
# Out:
# Heat Dissipation Failure    6462
# Power Failure               6373
# Overstrain Failure          6347
# Random Failures             6305
# Tool Wear Failure           6240
# No Failure                  6059
# Name: Failure Type, dtype: int64

# %%
df1.columns
# Out:
# Index(['Type', 'Air temperature [K]', 'Process temperature [K]',
#        'Rotational speed [rpm]', 'Failure Type'],
#       dtype='object')

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import (OneHotEncoder, PowerTransformer, StandardScaler)
from sklearn.impute import SimpleImputer

# %%
# Build categorical preprocessor
categorical_cols = X1_res.select_dtypes(include="object").columns.to_list()
categorical_pipe = make_pipeline(SimpleImputer(strategy='constant', fill_value='missing'),OneHotEncoder(sparse=False, handle_unknown="ignore"))

# Build numeric processor
to_log = ["Rotational speed [rpm]"]
to_scale = ["Air temperature [K]","Process temperature [K]"]
numeric_pipe_1 = make_pipeline(PowerTransformer())
numeric_pipe_2 = make_pipeline(StandardScaler())

# Full processor
full = ColumnTransformer(
    transformers=[
        ("categorical", categorical_pipe, categorical_cols),
        ("power_transform", numeric_pipe_1, to_log),
        ("standardization", numeric_pipe_2, to_scale)])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.multiclass import OutputCodeClassifier
rfc = OutputCodeClassifier(RandomForestClassifier(), code_size=6, random_state=40)

# %%
pipeline = Pipeline(
    steps=[("preprocess", full),("base",rfc)])

# %%
model_rfc = pipeline.fit(X1_res, y1_res)
y_pred_rfc = model_rfc.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
cm = confusion_matrix(y_test, y_pred_rfc)
print(classification_report(y_test, y_pred_rfc))
#cmp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=pipeline.classes_)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      3188
#            1       0.13      0.23      0.16        30
#            2       0.00      0.00      0.00        34
#            3       0.00      0.00      0.00        30
#            4       0.00      0.00      0.00        13
#            5       0.00      0.00      0.00         5
#
#     accuracy                           0.95      3300
#    macro avg       0.18      0.20      0.19      3300
# weighted avg       0.94      0.95      0.94      3300
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.metrics import accuracy_score
print("Accuracy Score: %.4f" %(accuracy_score(y_test,y_pred_rfc)))
# Out:
# Accuracy Score: 0.9512

# %%
y_pred_rfc.shape
# Out:
# (3300,)

# %%
y_test.shape
# Out:
# (3300,)

# %%
X1_res.columns
# Out:
# Index(['Type', 'Air temperature [K]', 'Process temperature [K]',
#        'Rotational speed [rpm]'],
#       dtype='object')

# %%
np.unique(y_pred_rfc,return_counts= True)
# Out:
# (array([0, 1, 2, 3, 4]), array([3231,   55,   11,    1,    2]))
